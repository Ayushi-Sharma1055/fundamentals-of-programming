# %%
def person(fname):
    print(fname+" sharma ")
person("ayushi")
# Out:
# ayushi sharma

# %%
person("anushka")
# Out:
# anushka sharma

# %%
person("aman")
# Out:
# aman sharma

# %%
def add(a,b):
    return a+b
add(2,3)
# Out:
# 5

# %%
add(77,89)
# Out:
# 166

# %%
def substract(a,b):
    return a-b
substract(99,89)
# Out:
# 10

# %%
substract(77,71)
# Out:
# 6

# %%
def division(a,b):
    return a/b
division(90,7)
# Out:
# 12.857142857142858

# %%
division(8099,23)
# Out:
# 352.1304347826087

# %%
def multiply(a,b):
    return a*b
multiply(90,78)
# Out:
# 7020

# %%
multiply(880,332)
# Out:
# 292160

# %%
def floor(a,b):
    return a//b
floor(78,2)
# Out:
# 39

# %%
def add(a,b):
    return a+b,b
add(89,90)
# Out:
# (179, 90)

# %%
def swap(a,b):
   a,b=b,a
   print(a)
   print(b)
swap(9,80)
# Out:
# 80
# 9
