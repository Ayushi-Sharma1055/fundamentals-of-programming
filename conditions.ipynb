# %%
age=20
if age>=18:
    print("eligible to vote")
# Out:
# eligible to vote

# %%
marks=90
if marks<=95:
    print("pass")
# Out:
# pass

# %%
salary=2000
if salary>=1000:
    print("bonus")
# Out:
# bonus

# %%
ID=18
if ID<=18:
    print("no alchol")
# Out:
# no alchol

# %%
 marks=33
if marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# fail

# %%
num=-10
if num >0:
    print("positive")
else:
    print("negative")
# Out:
# negative

# %%
num=20
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
age=20
if age>=18:
    print("eligible to vote")
# Out:
# eligible to vote

# %%
marks=90
if marks>=80:
    print("marks:A")
elif marks>=70:
    print("marks:B")
elif marks>=60:
    print("marks:C")
else:
    print("marks:F")
# Out:
# marks:A

# %%
num=int(input("enter a number:"))
if (num % 2)==0:
        print("number is even")
else:
        print("number is odd")
# Out:
# enter a number: 30
# number is even

# %%
i=0
while i<5:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=0
while i<10:
    print(i)
    i=i+2
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
i=1
while i<10:
    print(i)
    i=i+2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i=1
while i<10:
    print(i)
    if i ==4:
        break
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
while i<10:
    i+=1
    if i ==4:
       continue
    print(i)
# Out:
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# 10
