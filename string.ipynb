# %%
print('hello world')
# Out:
# hello world

# %%
a='hello world'
print(len(a))
# Out:
# 11

# %% [markdown]
# # slicing

# %%
b='hello world'
print(b[1:3])
# Out:
# el

# %%
print(b[2:6])
# Out:
# llo

# %%
print(b[:8])
# Out:
# hello wo

# %%
print(b[-8:-2])
# Out:
# lo wor

# %% [markdown]
# # modify string

# %%
a='hello world'
print(a.upper())
# Out:
# HELLO WORLD

# %%
print(a.lower())
# Out:
# hello world

# %% [markdown]
# # strip

# %%
a='hello world'
#remove whitespace from the starting and ending 
print(a.strip())
# Out:
# hello world

# %% [markdown]
# # string concatenation

# %%
#combine two strings you can use the + opreater
a="hello"
b="world"
c=a+" "+b
print(c)
# Out:
# hello world

# %% [markdown]
# # format method

# %%
#we can combine string and number by using format method with {}
age=23
text="my name is ayushi, and i am {}"
print(text.format(age))
# Out:
# my name is ayushi, and i am 23

# %% [markdown]
# # escape character

# %%
#to instert character that are illegal in a string 
text= "we are the so called\"vikings\" from the north."
print(text)
# Out:
# we are the so called"vikings" from the north.

# %% [markdown]
# # capitalize

# %%
txt="hello, and welcome to my wolrd."
x=txt.capitalize()
print(x)
# Out:
# Hello, and welcome to my wolrd.

# %% [markdown]
# # tittle method

# %%
txt="welcome to my wolrd"
y=txt.title()
print(y)
# Out:
# Welcome To My Wolrd

# %% [markdown]
# # count method

# %%
txt="hello, and welcome to my wolrd."
x=txt.count("my")
print(x)
# Out:
# 1

# %% [markdown]
# # string count

# %%
txt="hello, and welcome to my wolrd."
x=txt.count("and",9,11)
print(x)
# Out:
# 0

# %% [markdown]
# # find method

# %%
txt="hello, and welcome to my wolrd."
x=txt.find("my")
print(x)
# Out:
# 22

# %%
txt="hello, and welcome to my wolrd."
x=txt.find("o",2,10)
print(x)
# Out:
# 4

# %% [markdown]
# # split

# %%
txt="hello, and welcome to my wolrd."
x=txt.split()
print(x)
# Out:
# ['hello,', 'and', 'welcome', 'to', 'my', 'wolrd.']

# %% [markdown]
# # join method

# %%
tuple1=("peter","ayushi","henry")
x=":".join(tuple1)
print(x)
# Out:
# peter:ayushi:henry

# %%
tuple1=("peter","ayushi","henry")
x=":".join(tuple1)
print(x)
